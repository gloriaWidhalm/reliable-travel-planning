# %%
import pandas as pd
from collections import defaultdict

def generate_dynamic_route_graph(data, start_stop, start_time, target_stop=None):
    graph = defaultdict(list)
    paths = set()
    path_times = {}
    
    def build_line_path(stop, time, trip_identifier):
        next_stops = data[
            (data['TRIP_IDENTIFIER'] == trip_identifier) &
            (data['PLANNED_ARRIVAL'] > time)
        ].sort_values('PLANNED_ARRIVAL')
        
        transfers = data[
            (data['STOP_ID'] == stop) &
            (data['PLANNED_ARRIVAL'] > time) &
            (data['TRIP_IDENTIFIER'] != trip_identifier)
        ].sort_values('PLANNED_ARRIVAL')
        
        if not next_stops.empty:
            next_stop_data = next_stops.iloc[0]
            next_stop = next_stop_data['STOP_ID']
            next_time = next_stop_data['PLANNED_ARRIVAL']
            
            transition = (1, next_stop, next_time, trip_identifier)
            if transition not in graph[stop]:
                graph[stop].append(transition)
                build_line_path(next_stop, next_time, trip_identifier)
        
        for _, transfer in transfers.iterrows():
            new_trip_identifier = transfer['TRIP_IDENTIFIER']
            new_time = transfer['PLANNED_ARRIVAL']
            
            transition = (0, stop, new_time, new_trip_identifier)
            if transition not in graph[stop]:
                graph[stop].append(transition)
                build_line_path(stop, new_time, new_trip_identifier)
    
    def find_path(stop, time, trip_identifier, path=None, times=None, made_transfer=False):
        if path is None:
            path = []
        if times is None:
            times = []
            
        current_path = path + [f"{trip_identifier}'{stop}'"]
        current_times = times + [time]
        
        if stop == target_stop:
            path_str = '-'.join(current_path)
            paths.add(path_str)
            path_times[path_str] = current_times
            return
            
        for is_same_line, next_stop, next_time, next_trip_identifier in graph[stop]:
            if next_time <= time:
                continue
                
            if is_same_line == 0:
                if not made_transfer:
                    find_path(next_stop, next_time, next_trip_identifier, current_path, current_times, True)
            elif is_same_line == 1 and trip_identifier == next_trip_identifier:
                find_path(next_stop, next_time, next_trip_identifier, current_path, current_times, made_transfer)
    
    initial_routes = data[
        (data['STOP_ID'] == start_stop) & 
        (data['PLANNED_ARRIVAL'] >= start_time)
    ].sort_values('PLANNED_ARRIVAL')
    
    if not initial_routes.empty:
        initial_route = initial_routes.iloc[0]
        initial_trip_identifier = initial_route['TRIP_IDENTIFIER']
        initial_time = initial_route['PLANNED_ARRIVAL']
        
        build_line_path(start_stop, initial_time, initial_trip_identifier)
        find_path(start_stop, initial_time, initial_trip_identifier)
    
    formatted_graph = "Graph:\n"
    for stop in sorted(graph.keys()):
        formatted_graph += f"'{stop}': {graph[stop]}\n"
    
    # Format paths with times
    formatted_paths = []
    for path in sorted(list(paths)):
        times = path_times[path]
        stops = path.split('-')
        path_with_times = ' -> '.join([f"{stop}({time})" for stop, time in zip(stops, times)])
        formatted_paths.append(path_with_times)
    
    return formatted_graph, formatted_paths

# Test verisi
data = pd.DataFrame({
    'STOP_ID': ['A', 'B', 'C', 'D', 'E', 'B', 'C', 'D', 'E'],
    'TRIP_IDENTIFIER': ['T1', 'T1', 'T1', 'T1', 'T1', 'T2', 'T2', 'T2', 'T2'],
    'PLANNED_ARRIVAL': [800, 820, 840, 860, 880, 900, 920, 940, 960],
    'LINE_ID': ['L1', 'L1', 'L1', 'L1', 'L1', 'L2', 'L2', 'L2', 'L2']
})

start_stop = 'A'
start_time = 800
target_stop = 'E'
graph, paths = generate_dynamic_route_graph(data, start_stop, start_time, target_stop)
print(graph)
print("\nPossible Paths:")
for path in paths:
    print(path)
# Out:
# Graph:
# 'A': [(1, 'B', 820, 'T1')]
# 'B': [(1, 'C', 840, 'T1'), (0, 'B', 900, 'T2'), (1, 'C', 920, 'T2')]
# 'C': [(1, 'D', 860, 'T1'), (0, 'C', 920, 'T2'), (1, 'D', 940, 'T2')]
# 'D': [(1, 'E', 880, 'T1'), (0, 'D', 940, 'T2'), (1, 'E', 960, 'T2')]
# 'E': [(0, 'E', 960, 'T2')]
#
#
# Possible Paths:
# T1'A'(800) -> T1'B'(820) -> T1'C'(840) -> T1'D'(860) -> T1'E'(880)
# T1'A'(800) -> T1'B'(820) -> T1'C'(840) -> T1'D'(860) -> T2'D'(940) -> T2'E'(960)
# T1'A'(800) -> T1'B'(820) -> T1'C'(840) -> T2'C'(920) -> T2'D'(940) -> T2'E'(960)
# T1'A'(800) -> T1'B'(820) -> T2'B'(900) -> T2'C'(920) -> T2'D'(940) -> T2'E'(960)

# %%
import duckdb
import pandas as pd

# Connect to the database
connection = duckdb.connect("transport_data.db", read_only=False)

# %%
#Filter 1 month data
query = f""" 
SELECT *
FROM services 
WHERE PRODUCT_ID='Zug' 
AND ARRIVAL_PREDICTION_STATUS='REAL' 
AND DEPARTURE_PREDICTION_STATUS='REAL' 
AND strftime('%m',OPERATING_DAY)='10'
"""
df_Zug = connection.execute(query).df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
#select one day 
df_filtered=df_Zug[df_Zug['OPERATING_DAY']=='2024-10-02']

# %%
#create time column
df_filtered['time']=pd.to_datetime(df_filtered['DEPARTURE_TIME']).dt.time
# Out:
# C:\Users\ozgur\AppData\Local\Temp\ipykernel_5528\1839447244.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['time']=pd.to_datetime(df_filtered['DEPARTURE_TIME']).dt.time

# %%
#Filter related time interval
mask = (df_filtered['time'] >= pd.to_datetime('09:00').time()) & (df_filtered['time'] <= pd.to_datetime('11:00').time())
df_filtered = df_filtered[mask]

# %%
data =  df_filtered[['BPUIC', 'TRIP_IDENTIFIER', 'time', 'LINE_ID']].rename(columns={
   'BPUIC': 'STOP_ID',
   'time': 'PLANNED_ARRIVAL'
}).sort_values(['TRIP_IDENTIFIER','PLANNED_ARRIVAL'])
# Test
start_stop = 8503000
start_time = pd.to_datetime('09:00').time()
target_stop =8500218
graph, paths = generate_dynamic_route_graph(data, start_stop, start_time, target_stop)
print(graph)
print("\nPossible Paths:")
print('\n'.join(paths))
# Out:
# Graph:
# '8500010': [(1, 8500136, datetime.time(10, 40), 'ch:1:sjyid:100001:17334-001')]
# '8500020': [(0, 8500020, datetime.time(10, 54), 'ch:1:sjyid:100001:17239-002'), (1, 8500021, datetime.time(10, 58), 'ch:1:sjyid:100001:17239-002'), (1, 8500010, datetime.time(10, 37), 'ch:1:sjyid:100001:17334-001'), (0, 8500020, datetime.time(10, 24), 'ch:1:sjyid:100001:17137-001'), (1, 8500021, datetime.time(10, 28), 'ch:1:sjyid:100001:17137-001'), (0, 8500020, datetime.time(10, 37), 'ch:1:sjyid:100001:17335-001'), (1, 8500021, datetime.time(10, 41), 'ch:1:sjyid:100001:17335-001'), (0, 8500020, datetime.time(10, 49), 'ch:1:sjyid:100001:17336-001'), (0, 8500020, datetime.time(10, 34), 'ch:1:sjyid:100001:17136-001')]
# '8500021': [(1, 8500020, datetime.time(10, 49), 'ch:1:sjyid:100001:17336-001'), (1, 8517131, datetime.time(11, 0), 'ch:1:sjyid:100001:17239-002'), (0, 8500021, datetime.time(10, 58), 'ch:1:sjyid:100001:17239-002'), (1, 8500020, datetime.time(10, 21), 'ch:1:sjyid:100001:17334-001'), (1, 8517131, datetime.time(10, 30), 'ch:1:sjyid:100001:17137-001'), (0, 8500021, datetime.time(10, 31), 'ch:1:sjyid:100001:17136-001'), (1, 8500020, datetime.time(10, 34), 'ch:1:sjyid:100001:17136-001'), (1, 8500022, datetime.time(10, 44), 'ch:1:sjyid:100001:17335-001'), (0, 8500021, datetime.time(10, 46), 'ch:1:sjyid:100001:17336-001'), (0, 8500021, datetime.time(10, 41), 'ch:1:sjyid:100001:17335-001'), (0, 8500021, datetime.time(10, 28), 'ch:1:sjyid:100001:17137-001')]
# '8500022': [(1, 8500021, datetime.time(10, 46), 'ch:1:sjyid:100001:17336-001'), (0, 8500022, datetime.time(10, 44), 'ch:1:sjyid:100001:17335-001'), (1, 8500023, datetime.time(10, 48), 'ch:1:sjyid:100001:17335-001'), (1, 8500021, datetime.time(10, 18), 'ch:1:sjyid:100001:17334-001'), (0, 8500022, datetime.time(10, 41), 'ch:1:sjyid:100001:17336-001')]
# '8500023': [(0, 8500023, datetime.time(10, 54), 'ch:1:sjyid:100001:2267-001'), (0, 8500023, datetime.time(10, 38), 'ch:1:sjyid:100001:17336-001'), (1, 8500022, datetime.time(10, 41), 'ch:1:sjyid:100001:17336-001'), (1, 8500024, datetime.time(10, 51), 'ch:1:sjyid:100001:17335-001'), (0, 8500023, datetime.time(10, 50), 'ch:1:sjyid:100001:964-001'), (0, 8500023, datetime.time(10, 48), 'ch:1:sjyid:100001:17335-001'), (0, 8500023, datetime.time(10, 7), 'ch:1:sjyid:100001:965-002'), (1, 8500218, datetime.time(10, 29), 'ch:1:sjyid:100001:965-002'), (0, 8500023, datetime.time(10, 11), 'ch:1:sjyid:100001:17334-001'), (1, 8500022, datetime.time(10, 14), 'ch:1:sjyid:100001:17334-001'), (0, 8500023, datetime.time(10, 18), 'ch:1:sjyid:100001:17333-001'), (1, 8500024, datetime.time(10, 21), 'ch:1:sjyid:100001:17333-001'), (0, 8500023, datetime.time(10, 27), 'ch:1:sjyid:100001:2467-001'), (1, 8500026, datetime.time(10, 33), 'ch:1:sjyid:100001:2467-001'), (0, 8500023, datetime.time(10, 34), 'ch:1:sjyid:100001:2464-001')]
# '8500024': [(1, 8500025, datetime.time(10, 53), 'ch:1:sjyid:100001:17335-001'), (1, 8500023, datetime.time(10, 38), 'ch:1:sjyid:100001:17336-001'), (0, 8500024, datetime.time(10, 51), 'ch:1:sjyid:100001:17335-001'), (1, 8500025, datetime.time(10, 23), 'ch:1:sjyid:100001:17333-001'), (0, 8500024, datetime.time(10, 35), 'ch:1:sjyid:100001:17336-001'), (1, 8500023, datetime.time(10, 11), 'ch:1:sjyid:100001:17334-001'), (0, 8500024, datetime.time(10, 21), 'ch:1:sjyid:100001:17333-001')]
# '8500025': [(1, 8500026, datetime.time(10, 56), 'ch:1:sjyid:100001:17335-001'), (1, 8500024, datetime.time(10, 35), 'ch:1:sjyid:100001:17336-001'), (0, 8500025, datetime.time(10, 53), 'ch:1:sjyid:100001:17335-001'), (1, 8500026, datetime.time(10, 26), 'ch:1:sjyid:100001:17333-001'), (0, 8500025, datetime.time(10, 33), 'ch:1:sjyid:100001:17336-001'), (1, 8500024, datetime.time(10, 7), 'ch:1:sjyid:100001:17334-001'), (0, 8500025, datetime.time(10, 23), 'ch:1:sjyid:100001:17333-001')]
# '8500026': [(0, 8500026, datetime.time(10, 56), 'ch:1:sjyid:100001:17335-001'), (1, 8500027, datetime.time(10, 59), 'ch:1:sjyid:100001:17335-001'), (1, 8500023, datetime.time(10, 34), 'ch:1:sjyid:100001:2464-001'), (0, 8500026, datetime.time(10, 31), 'ch:1:sjyid:100001:17336-001'), (1, 8500025, datetime.time(10, 33), 'ch:1:sjyid:100001:17336-001'), (0, 8500026, datetime.time(10, 33), 'ch:1:sjyid:100001:2467-001'), (1, 8500027, datetime.time(10, 37), 'ch:1:sjyid:100001:2467-001'), (0, 8500026, datetime.time(10, 55), 'ch:1:sjyid:100001:2262-001'), (1, 8500023, datetime.time(10, 2), 'ch:1:sjyid:100001:2260-001'), (1, 8500027, datetime.time(10, 29), 'ch:1:sjyid:100001:17333-001'), (0, 8500026, datetime.time(10, 27), 'ch:1:sjyid:100001:2464-001'), (0, 8500026, datetime.time(9, 56), 'ch:1:sjyid:100001:17331-001'), (1, 8500027, datetime.time(9, 59), 'ch:1:sjyid:100001:17331-001'), (0, 8500026, datetime.time(10, 1), 'ch:1:sjyid:100001:2265-001'), (1, 8502113, datetime.time(10, 23), 'ch:1:sjyid:100001:2265-001'), (0, 8500026, datetime.time(10, 3), 'ch:1:sjyid:100001:17334-001'), (1, 8500025, datetime.time(10, 5), 'ch:1:sjyid:100001:17334-001'), (0, 8500026, datetime.time(10, 26), 'ch:1:sjyid:100001:17333-001')]
# '8500027': [(1, 8500026, datetime.time(10, 27), 'ch:1:sjyid:100001:2464-001'), (1, 8500218, datetime.time(10, 49), 'ch:1:sjyid:100001:2467-001'), (0, 8500027, datetime.time(10, 59), 'ch:1:sjyid:100001:17335-001'), (0, 8500027, datetime.time(10, 59), 'ch:1:sjyid:100001:17338-001'), (0, 8500027, datetime.time(10, 27), 'ch:1:sjyid:100001:17336-001'), (1, 8500026, datetime.time(10, 31), 'ch:1:sjyid:100001:17336-001'), (0, 8500027, datetime.time(10, 29), 'ch:1:sjyid:100001:17333-001'), (1, 8500028, datetime.time(10, 32), 'ch:1:sjyid:100001:17333-001'), (0, 8500027, datetime.time(10, 37), 'ch:1:sjyid:100001:2467-001'), (1, 8500028, datetime.time(10, 2), 'ch:1:sjyid:100001:17331-001'), (0, 8500027, datetime.time(10, 22), 'ch:1:sjyid:100001:2464-001')]
# '8500028': [(0, 8500028, datetime.time(10, 55), 'ch:1:sjyid:100001:17338-001'), (1, 8500027, datetime.time(10, 59), 'ch:1:sjyid:100001:17338-001'), (0, 8500028, datetime.time(10, 24), 'ch:1:sjyid:100001:17336-001'), (1, 8500027, datetime.time(10, 27), 'ch:1:sjyid:100001:17336-001'), (0, 8500028, datetime.time(10, 32), 'ch:1:sjyid:100001:17333-001')]
# '8500115': [(1, 8500114, datetime.time(10, 59), 'ch:1:sjyid:100001:17334-001')]
# '8500116': [(1, 8500115, datetime.time(10, 54), 'ch:1:sjyid:100001:17334-001')]
# '8500117': [(1, 8500116, datetime.time(10, 51), 'ch:1:sjyid:100001:17334-001')]
# '8500118': [(1, 8500117, datetime.time(10, 49), 'ch:1:sjyid:100001:17334-001')]
# '8500119': [(1, 8500118, datetime.time(10, 46), 'ch:1:sjyid:100001:17334-001'), (0, 8500119, datetime.time(10, 44), 'ch:1:sjyid:100001:17337-001'), (1, 8500136, datetime.time(10, 47), 'ch:1:sjyid:100001:17337-001')]
# '8500136': [(1, 8500119, datetime.time(10, 43), 'ch:1:sjyid:100001:17334-001'), (0, 8500136, datetime.time(10, 47), 'ch:1:sjyid:100001:17337-001')]
# '8500200': [(1, 8518771, datetime.time(11, 0), 'ch:1:sjyid:100001:7618-001'), (1, 8518771, datetime.time(10, 31), 'ch:1:sjyid:100001:7664-001'), (0, 8500200, datetime.time(10, 30), 'ch:1:sjyid:100001:7667-001'), (1, 8500201, datetime.time(10, 32), 'ch:1:sjyid:100001:7667-001'), (0, 8500200, datetime.time(10, 57), 'ch:1:sjyid:100001:7618-001')]
# '8500201': [(1, 8500200, datetime.time(10, 57), 'ch:1:sjyid:100001:7618-001'), (1, 8500200, datetime.time(10, 28), 'ch:1:sjyid:100001:7664-001'), (1, 8500202, datetime.time(10, 35), 'ch:1:sjyid:100001:7667-001'), (0, 8500201, datetime.time(10, 55), 'ch:1:sjyid:100001:7618-001'), (0, 8500201, datetime.time(10, 32), 'ch:1:sjyid:100001:7667-001')]
# '8500202': [(1, 8500207, datetime.time(10, 34), 'ch:1:sjyid:100001:1517-001'), (0, 8500202, datetime.time(10, 34), 'ch:1:sjyid:100001:1514-001'), (1, 8504300, datetime.time(10, 45), 'ch:1:sjyid:100001:1514-001'), (0, 8500202, datetime.time(10, 35), 'ch:1:sjyid:100001:7667-001'), (1, 8500203, datetime.time(10, 38), 'ch:1:sjyid:100001:7667-001'), (1, 8500201, datetime.time(10, 55), 'ch:1:sjyid:100001:7618-001'), (0, 8500202, datetime.time(10, 52), 'ch:1:sjyid:100001:7618-001'), (1, 8500201, datetime.time(10, 26), 'ch:1:sjyid:100001:7664-001'), (0, 8500202, datetime.time(10, 26), 'ch:1:sjyid:100001:1517-001')]
# '8500203': [(1, 8500204, datetime.time(10, 40), 'ch:1:sjyid:100001:7667-001'), (1, 8500202, datetime.time(10, 52), 'ch:1:sjyid:100001:7618-001'), (0, 8500203, datetime.time(10, 49), 'ch:1:sjyid:100001:7618-001'), (1, 8500202, datetime.time(10, 23), 'ch:1:sjyid:100001:7664-001'), (0, 8500203, datetime.time(10, 38), 'ch:1:sjyid:100001:7667-001')]
# '8500204': [(1, 8500205, datetime.time(10, 43), 'ch:1:sjyid:100001:7667-001'), (0, 8500204, datetime.time(10, 47), 'ch:1:sjyid:100001:7618-001'), (1, 8500203, datetime.time(10, 49), 'ch:1:sjyid:100001:7618-001'), (1, 8500203, datetime.time(10, 20), 'ch:1:sjyid:100001:7664-001'), (0, 8500204, datetime.time(10, 40), 'ch:1:sjyid:100001:7667-001')]
# '8500205': [(1, 8518963, datetime.time(10, 45), 'ch:1:sjyid:100001:7667-001'), (1, 8500204, datetime.time(10, 18), 'ch:1:sjyid:100001:7664-001'), (0, 8500205, datetime.time(10, 43), 'ch:1:sjyid:100001:7618-001'), (1, 8500204, datetime.time(10, 47), 'ch:1:sjyid:100001:7618-001'), (0, 8500205, datetime.time(10, 43), 'ch:1:sjyid:100001:7667-001')]
# '8500206': [(1, 8500207, datetime.time(10, 49), 'ch:1:sjyid:100001:7667-001'), (1, 8518963, datetime.time(10, 13), 'ch:1:sjyid:100001:7664-001'), (0, 8500206, datetime.time(10, 22), 'ch:1:sjyid:100001:7836-002'), (0, 8500206, datetime.time(10, 33), 'ch:1:sjyid:100001:7839-002'), (1, 8500261, datetime.time(10, 36), 'ch:1:sjyid:100001:7839-002'), (0, 8500206, datetime.time(10, 40), 'ch:1:sjyid:100001:7618-001'), (1, 8518963, datetime.time(10, 42), 'ch:1:sjyid:100001:7618-001'), (0, 8500206, datetime.time(10, 47), 'ch:1:sjyid:100001:7667-001'), (0, 8500206, datetime.time(10, 18), 'ch:1:sjyid:100001:7617-001')]
# '8500207': [(1, 8504300, datetime.time(10, 16), 'ch:1:sjyid:100001:514-003'), (1, 8500212, datetime.time(10, 46), 'ch:1:sjyid:100001:1517-001'), (0, 8500207, datetime.time(10, 49), 'ch:1:sjyid:100001:7667-001'), (1, 8500208, datetime.time(10, 52), 'ch:1:sjyid:100001:7667-001'), (0, 8500207, datetime.time(10, 58), 'ch:1:sjyid:100001:516-001'), (0, 8500207, datetime.time(10, 1), 'ch:1:sjyid:100001:515-001'), (1, 8500218, datetime.time(10, 20), 'ch:1:sjyid:100001:515-001'), (0, 8500207, datetime.time(10, 10), 'ch:1:sjyid:100001:7664-001'), (1, 8500206, datetime.time(10, 11), 'ch:1:sjyid:100001:7664-001'), (0, 8500207, datetime.time(10, 26), 'ch:1:sjyid:100001:1514-001'), (1, 8500202, datetime.time(10, 34), 'ch:1:sjyid:100001:1514-001'), (0, 8500207, datetime.time(10, 34), 'ch:1:sjyid:100001:1517-001')]
# '8500208': [(1, 8500209, datetime.time(10, 55), 'ch:1:sjyid:100001:7667-001'), (0, 8500208, datetime.time(10, 52), 'ch:1:sjyid:100001:7667-001')]
# '8500209': [(1, 8500210, datetime.time(10, 58), 'ch:1:sjyid:100001:7667-001'), (1, 8500208, datetime.time(10, 41), 'ch:1:sjyid:100001:7716-003'), (0, 8500209, datetime.time(10, 55), 'ch:1:sjyid:100001:7667-001')]
# '8500210': [(0, 8500210, datetime.time(11, 0), 'ch:1:sjyid:100001:7666-001'), (1, 8500209, datetime.time(10, 38), 'ch:1:sjyid:100001:7716-003'), (0, 8500210, datetime.time(10, 58), 'ch:1:sjyid:100001:7667-001')]
# '8500211': [(1, 8500210, datetime.time(11, 0), 'ch:1:sjyid:100001:7666-001'), (1, 8500210, datetime.time(10, 36), 'ch:1:sjyid:100001:7716-003'), (0, 8500211, datetime.time(10, 37), '85:81:9428:000'), (1, 8518690, datetime.time(10, 38), '85:81:9428:000'), (1, 8508159, datetime.time(10, 47), '85:81:428:000'), (0, 8500211, datetime.time(10, 49), '85:81:9427:000'), (1, 8500289, datetime.time(10, 50), '85:81:9427:000'), (0, 8500211, datetime.time(10, 54), 'ch:1:sjyid:100001:7666-001'), (0, 8500211, datetime.time(10, 39), '85:81:427:000'), (1, 8518690, datetime.time(10, 40), '85:81:427:000'), (0, 8500211, datetime.time(10, 46), '85:81:428:000')]
# '8500212': [(1, 8500218, datetime.time(10, 59), 'ch:1:sjyid:100001:1517-001'), (0, 8500212, datetime.time(10, 52), 'ch:1:sjyid:100001:7666-001'), (1, 8500211, datetime.time(10, 54), 'ch:1:sjyid:100001:7666-001'), (1, 8500207, datetime.time(10, 26), 'ch:1:sjyid:100001:1514-001'), (0, 8500212, datetime.time(10, 28), 'ch:1:sjyid:100001:7716-003'), (1, 8500211, datetime.time(10, 30), 'ch:1:sjyid:100001:7716-003'), (0, 8500212, datetime.time(10, 32), 'ch:1:sjyid:100001:7717-003'), (1, 8500213, datetime.time(10, 35), 'ch:1:sjyid:100001:7717-003'), (0, 8500212, datetime.time(10, 46), 'ch:1:sjyid:100001:1517-001')]
# '8500213': [(1, 8500214, datetime.time(10, 38), 'ch:1:sjyid:100001:7717-003'), (1, 8500212, datetime.time(10, 52), 'ch:1:sjyid:100001:7666-001'), (0, 8500213, datetime.time(10, 48), 'ch:1:sjyid:100001:7666-001')]
# '8500214': [(1, 8500215, datetime.time(10, 41), 'ch:1:sjyid:100001:7717-003'), (1, 8500213, datetime.time(10, 48), 'ch:1:sjyid:100001:7666-001'), (0, 8500214, datetime.time(10, 46), 'ch:1:sjyid:100001:7666-001')]
# '8500215': [(1, 8500216, datetime.time(10, 44), 'ch:1:sjyid:100001:7717-003'), (0, 8500215, datetime.time(10, 42), 'ch:1:sjyid:100001:7666-001'), (1, 8500214, datetime.time(10, 46), 'ch:1:sjyid:100001:7666-001')]
# '8500216': [(1, 8500217, datetime.time(10, 46), 'ch:1:sjyid:100001:7717-003')]
# '8500218': [(1, 8500207, datetime.time(10, 58), 'ch:1:sjyid:100001:516-001'), (0, 8500218, datetime.time(10, 49), 'ch:1:sjyid:100001:2467-001'), (1, 8502001, datetime.time(10, 58), 'ch:1:sjyid:100001:2467-001'), (0, 8500218, datetime.time(10, 55), 'ch:1:sjyid:100001:8436-001'), (1, 8502000, datetime.time(10, 59), 'ch:1:sjyid:100001:8436-001'), (0, 8500218, datetime.time(10, 56), 'ch:1:sjyid:100001:2166-001'), (0, 8500218, datetime.time(10, 58), 'ch:1:sjyid:100001:1067-001'), (0, 8500218, datetime.time(10, 59), 'ch:1:sjyid:100001:1517-001'), (0, 8500218, datetime.time(10, 49), 'ch:1:sjyid:100001:8941-001'), (1, 8502113, datetime.time(10, 58), 'ch:1:sjyid:100001:8941-001'), (1, 8508100, datetime.time(10, 48), 'ch:1:sjyid:100061:2362-005'), (0, 8500218, datetime.time(10, 40), 'ch:1:sjyid:100001:516-001'), (1, 8502000, datetime.time(10, 40), 'ch:1:sjyid:100001:8936-001'), (1, 8502000, datetime.time(10, 16), 'ch:1:sjyid:100001:8934-001'), (1, 8502113, datetime.time(10, 34), 'ch:1:sjyid:100001:8939-001'), (0, 8500218, datetime.time(10, 29), 'ch:1:sjyid:100001:965-002'), (0, 8500218, datetime.time(10, 30), 'ch:1:sjyid:100001:2365-007'), (1, 8503001, datetime.time(11, 0), 'ch:1:sjyid:100001:2365-007'), (0, 8500218, datetime.time(10, 33), 'ch:1:sjyid:100001:964-001'), (1, 8500023, datetime.time(10, 50), 'ch:1:sjyid:100001:964-001'), (0, 8500218, datetime.time(10, 36), 'ch:1:sjyid:100001:8936-001'), (0, 8500218, datetime.time(10, 36), 'ch:1:sjyid:100061:2362-005'), (0, 8500218, datetime.time(10, 30), 'ch:1:sjyid:100001:668-001'), (0, 8500218, datetime.time(10, 30), 'ch:1:sjyid:100061:2319-001'), (0, 8500218, datetime.time(10, 20), 'ch:1:sjyid:100001:515-001'), (1, 8502113, datetime.time(10, 31), 'ch:1:sjyid:100001:515-001'), (0, 8500218, datetime.time(10, 23), 'ch:1:sjyid:100001:8939-001'), (1, 8500207, datetime.time(9, 58), 'ch:1:sjyid:100001:514-003'), (0, 8500218, datetime.time(9, 49), 'ch:1:sjyid:100001:8937-001'), (1, 8502113, datetime.time(9, 58), 'ch:1:sjyid:100001:8937-001'), (0, 8500218, datetime.time(9, 55), 'ch:1:sjyid:100001:8432-001'), (1, 8502000, datetime.time(9, 59), 'ch:1:sjyid:100001:8432-001'), (0, 8500218, datetime.time(9, 56), 'ch:1:sjyid:100001:2164-001'), (0, 8500218, datetime.time(9, 58), 'ch:1:sjyid:100001:1065-002'), (1, 8507000, datetime.time(10, 34), 'ch:1:sjyid:100001:1065-002'), (0, 8500218, datetime.time(9, 59), 'ch:1:sjyid:100001:1515-001'), (0, 8500218, datetime.time(10, 2), 'ch:1:sjyid:100001:1514-001'), (1, 8500212, datetime.time(10, 14), 'ch:1:sjyid:100001:1514-001'), (0, 8500218, datetime.time(10, 5), 'ch:1:sjyid:100001:8437-001'), (1, 8502110, datetime.time(10, 9), 'ch:1:sjyid:100001:8437-001'), (0, 8500218, datetime.time(10, 6), 'ch:1:sjyid:100001:1062-007'), (0, 8500218, datetime.time(10, 12), 'ch:1:sjyid:100001:2464-001'), (1, 8500027, datetime.time(10, 22), 'ch:1:sjyid:100001:2464-001'), (0, 8500218, datetime.time(10, 12), 'ch:1:sjyid:100001:8934-001'), (0, 8500218, datetime.time(10, 2), 'ch:1:sjyid:100001:2167-001'), (1, 8502113, datetime.time(10, 14), 'ch:1:sjyid:100001:2167-001'), (0, 8500218, datetime.time(9, 49), 'ch:1:sjyid:100001:2465-001'), (1, 8502001, datetime.time(9, 58), 'ch:1:sjyid:100001:2465-001')]
# '8500261': [(1, 8500262, datetime.time(10, 40), 'ch:1:sjyid:100001:7839-002')]
# '8500262': [(1, 8500263, datetime.time(10, 43), 'ch:1:sjyid:100001:7839-002')]
# '8500286': [(1, 8500285, datetime.time(10, 59), '85:81:9427:000'), (0, 8500286, datetime.time(10, 58), '85:81:9430:000')]
# '8500287': [(1, 8500286, datetime.time(10, 57), '85:81:9427:000')]
# '8500288': [(1, 8500287, datetime.time(10, 54), '85:81:9427:000')]
# '8500289': [(1, 8500288, datetime.time(10, 52), '85:81:9427:000')]
# '8500300': [(1, 8517131, datetime.time(10, 58), 'ch:1:sjyid:100001:17238-002'), (1, 8500313, datetime.time(10, 35), 'ch:1:sjyid:100001:17137-001'), (0, 8500300, datetime.time(10, 57), 'ch:1:sjyid:100001:17238-002')]
# '8500301': [(0, 8500301, datetime.time(10, 38), 'ch:1:sjyid:100001:17137-001'), (1, 8500302, datetime.time(10, 41), 'ch:1:sjyid:100001:17137-001'), (0, 8500301, datetime.time(10, 52), 'ch:1:sjyid:100001:17238-002'), (1, 8500313, datetime.time(10, 54), 'ch:1:sjyid:100001:17238-002')]
# '8500302': [(1, 8500303, datetime.time(10, 45), 'ch:1:sjyid:100001:17137-001')]
# '8500303': [(1, 8500320, datetime.time(10, 49), 'ch:1:sjyid:100001:17137-001')]
# '8500305': [(1, 8500320, datetime.time(10, 25), 'ch:1:sjyid:100001:1964-001'), (1, 8500309, datetime.time(11, 0), 'ch:1:sjyid:100001:1967-001'), (0, 8500305, datetime.time(10, 42), 'ch:1:sjyid:100001:1967-001')]
# '8500309': [(0, 8500309, datetime.time(10, 43), 'ch:1:sjyid:100001:8938-001'), (1, 8502116, datetime.time(10, 47), 'ch:1:sjyid:100001:8938-001'), (0, 8500309, datetime.time(10, 45), 'ch:1:sjyid:100001:8437-001'), (1, 8503503, datetime.time(10, 49), 'ch:1:sjyid:100001:8437-001'), (0, 8500309, datetime.time(10, 52), 'ch:1:sjyid:100001:8939-001'), (0, 8500309, datetime.time(11, 0), 'ch:1:sjyid:100001:1967-001'), (0, 8500309, datetime.time(11, 0), 'ch:1:sjyid:100001:4766-001'), (1, 8502113, datetime.time(10, 46), 'ch:1:sjyid:100001:2166-001'), (0, 8500309, datetime.time(10, 41), 'ch:1:sjyid:100001:2066-002'), (1, 8502115, datetime.time(10, 7), 'ch:1:sjyid:100001:4764-001'), (1, 8503504, datetime.time(10, 38), 'ch:1:sjyid:100001:2167-001'), (0, 8500309, datetime.time(10, 32), 'ch:1:sjyid:100001:2166-001'), (0, 8500309, datetime.time(10, 2), 'ch:1:sjyid:100001:1964-001'), (1, 8500305, datetime.time(10, 18), 'ch:1:sjyid:100001:1964-001'), (0, 8500309, datetime.time(10, 3), 'ch:1:sjyid:100001:4765-001'), (1, 8503503, datetime.time(10, 7), 'ch:1:sjyid:100001:4765-001'), (1, 8502237, datetime.time(10, 18), 'ch:1:sjyid:100001:8436-001'), (0, 8500309, datetime.time(10, 20), 'ch:1:sjyid:100001:2065-002'), (1, 8503504, datetime.time(10, 29), 'ch:1:sjyid:100001:2065-002'), (0, 8500309, datetime.time(10, 22), 'ch:1:sjyid:100001:8937-001'), (0, 8500309, datetime.time(10, 30), 'ch:1:sjyid:100001:2167-001'), (0, 8500309, datetime.time(10, 7), 'ch:1:sjyid:100001:8936-001'), (1, 8502116, datetime.time(10, 11), 'ch:1:sjyid:100001:8936-001'), (0, 8500309, datetime.time(10, 14), 'ch:1:sjyid:100001:8436-001'), (0, 8500309, datetime.time(9, 43), 'ch:1:sjyid:100001:8934-001'), (1, 8502116, datetime.time(9, 47), 'ch:1:sjyid:100001:8934-001'), (0, 8500309, datetime.time(9, 45), 'ch:1:sjyid:100001:8433-001'), (1, 8503503, datetime.time(9, 49), 'ch:1:sjyid:100001:8433-001'), (0, 8500309, datetime.time(9, 52), 'ch:1:sjyid:100001:8935-001'), (0, 8500309, datetime.time(10, 0), 'ch:1:sjyid:100001:1965-001'), (1, 8503504, datetime.time(10, 8), 'ch:1:sjyid:100001:1965-001'), (0, 8500309, datetime.time(10, 0), 'ch:1:sjyid:100001:4764-001')]
# '8500313': [(1, 8500300, datetime.time(10, 57), 'ch:1:sjyid:100001:17238-002'), (1, 8500301, datetime.time(10, 38), 'ch:1:sjyid:100001:17137-001'), (0, 8500313, datetime.time(10, 54), 'ch:1:sjyid:100001:17238-002')]
# '8500320': [(1, 8500301, datetime.time(10, 34), 'ch:1:sjyid:100001:1964-001'), (1, 8500304, datetime.time(10, 52), 'ch:1:sjyid:100001:17137-001'), (0, 8500320, datetime.time(10, 35), 'ch:1:sjyid:100001:1967-001'), (1, 8500305, datetime.time(10, 42), 'ch:1:sjyid:100001:1967-001'), (0, 8500320, datetime.time(10, 49), 'ch:1:sjyid:100001:17137-001')]
# '8500329': [(1, 8503411, datetime.time(10, 48), 'ch:1:sjyid:100001:8734-001')]
# '8502000': [(1, 8502001, datetime.time(10, 44), 'ch:1:sjyid:100001:8936-001'), (0, 8502000, datetime.time(10, 44), 'ch:1:sjyid:100001:8941-001'), (1, 8500218, datetime.time(10, 49), 'ch:1:sjyid:100001:8941-001'), (0, 8502000, datetime.time(10, 59), 'ch:1:sjyid:100001:8436-001'), (0, 8502000, datetime.time(10, 59), 'ch:1:sjyid:100001:8441-001'), (0, 8502000, datetime.time(10, 17), 'ch:1:sjyid:100001:8939-001'), (1, 8500218, datetime.time(10, 23), 'ch:1:sjyid:100001:8939-001'), (0, 8502000, datetime.time(10, 20), 'ch:1:sjyid:100001:8434-001'), (1, 8508103, datetime.time(10, 24), 'ch:1:sjyid:100001:8434-001'), (0, 8502000, datetime.time(10, 40), 'ch:1:sjyid:100001:8936-001'), (0, 8502000, datetime.time(10, 36), 'ch:1:sjyid:100001:8439-001'), (1, 8508103, datetime.time(10, 2), 'ch:1:sjyid:100001:8432-001'), (0, 8502000, datetime.time(10, 16), 'ch:1:sjyid:100001:8934-001')]
# '8502001': [(1, 8502002, datetime.time(10, 47), 'ch:1:sjyid:100001:8936-001'), (0, 8502001, datetime.time(10, 45), 'ch:1:sjyid:100001:4716-001'), (0, 8502001, datetime.time(10, 58), 'ch:1:sjyid:100001:2467-001'), (1, 8502007, datetime.time(10, 12), 'ch:1:sjyid:100001:2465-001'), (0, 8502001, datetime.time(10, 44), 'ch:1:sjyid:100001:8936-001'), (0, 8502001, datetime.time(10, 3), 'ch:1:sjyid:100001:2464-001'), (1, 8500218, datetime.time(10, 12), 'ch:1:sjyid:100001:2464-001'), (0, 8502001, datetime.time(10, 13), 'ch:1:sjyid:100001:4717-001'), (1, 8502003, datetime.time(10, 16), 'ch:1:sjyid:100001:4717-001'), (0, 8502001, datetime.time(10, 29), 'ch:1:sjyid:100001:2513-002'), (1, 8502007, datetime.time(10, 42), 'ch:1:sjyid:100001:2513-002'), (0, 8502001, datetime.time(10, 32), 'ch:1:sjyid:100001:2516-001'), (0, 8502001, datetime.time(10, 13), 'ch:1:sjyid:100001:8939-001'), (1, 8502000, datetime.time(10, 17), 'ch:1:sjyid:100001:8939-001')]
# '8502002': [(1, 8502003, datetime.time(10, 50), 'ch:1:sjyid:100001:8936-001')]
# '8502003': [(1, 8502004, datetime.time(10, 53), 'ch:1:sjyid:100001:8936-001'), (1, 8502001, datetime.time(10, 45), 'ch:1:sjyid:100001:4716-001'), (0, 8502003, datetime.time(10, 50), 'ch:1:sjyid:100001:8936-001'), (1, 8502004, datetime.time(10, 19), 'ch:1:sjyid:100001:4717-001'), (0, 8502003, datetime.time(10, 40), 'ch:1:sjyid:100001:4716-001')]
# '8502004': [(1, 8502005, datetime.time(10, 57), 'ch:1:sjyid:100001:8936-001'), (1, 8502003, datetime.time(10, 40), 'ch:1:sjyid:100001:4716-001'), (0, 8502004, datetime.time(10, 53), 'ch:1:sjyid:100001:8936-001'), (1, 8502005, datetime.time(10, 22), 'ch:1:sjyid:100001:4717-001'), (0, 8502004, datetime.time(10, 37), 'ch:1:sjyid:100001:4716-001')]
# '8502005': [(1, 8502006, datetime.time(11, 0), 'ch:1:sjyid:100001:8936-001'), (1, 8502004, datetime.time(10, 37), 'ch:1:sjyid:100001:4716-001'), (0, 8502005, datetime.time(10, 57), 'ch:1:sjyid:100001:8936-001'), (1, 8502006, datetime.time(10, 26), 'ch:1:sjyid:100001:4717-001'), (0, 8502005, datetime.time(10, 35), 'ch:1:sjyid:100001:4716-001')]
# '8502006': [(1, 8502005, datetime.time(10, 35), 'ch:1:sjyid:100001:4716-001'), (0, 8502006, datetime.time(10, 57), 'ch:1:sjyid:100001:8943-001'), (0, 8502006, datetime.time(11, 0), 'ch:1:sjyid:100001:8936-001'), (1, 8502007, datetime.time(10, 31), 'ch:1:sjyid:100001:4717-001'), (0, 8502006, datetime.time(10, 31), 'ch:1:sjyid:100001:4716-001')]
# '8502007': [(0, 8502007, datetime.time(10, 18), 'ch:1:sjyid:100001:2516-001'), (1, 8502001, datetime.time(10, 32), 'ch:1:sjyid:100001:2516-001'), (0, 8502007, datetime.time(10, 27), 'ch:1:sjyid:100001:4716-001'), (1, 8502006, datetime.time(10, 31), 'ch:1:sjyid:100001:4716-001'), (0, 8502007, datetime.time(10, 31), 'ch:1:sjyid:100001:4717-001'), (1, 8502009, datetime.time(10, 37), 'ch:1:sjyid:100001:4717-001'), (0, 8502007, datetime.time(10, 42), 'ch:1:sjyid:100001:2513-002'), (0, 8502007, datetime.time(10, 48), 'ch:1:sjyid:100001:2466-001')]
# '8502009': [(1, 8502020, datetime.time(10, 42), 'ch:1:sjyid:100001:4717-001'), (0, 8502009, datetime.time(10, 57), 'ch:1:sjyid:100001:21134-001')]
# '8502012': [(1, 8502020, datetime.time(10, 57), 'ch:1:sjyid:100001:21131-001')]
# '8502020': [(1, 8502021, datetime.time(10, 47), 'ch:1:sjyid:100001:4717-001'), (0, 8502020, datetime.time(10, 57), 'ch:1:sjyid:100001:21131-001')]
# '8502021': [(1, 8502028, datetime.time(10, 52), 'ch:1:sjyid:100001:21131-001'), (0, 8502021, datetime.time(10, 50), 'ch:1:sjyid:100001:21937-001'), (0, 8502021, datetime.time(10, 49), 'ch:1:sjyid:100001:21131-001')]
# '8502028': [(1, 8502012, datetime.time(10, 54), 'ch:1:sjyid:100001:21131-001')]
# '8502105': [(1, 8502119, datetime.time(10, 35), 'ch:1:sjyid:100001:19136-001'), (0, 8502105, datetime.time(11, 0), 'ch:1:sjyid:100001:19138-001'), (0, 8502105, datetime.time(10, 34), 'ch:1:sjyid:100001:8437-001'), (1, 8502247, datetime.time(10, 37), 'ch:1:sjyid:100001:8437-001'), (1, 8502211, datetime.time(10, 44), 'ch:1:sjyid:100001:8539-001'), (0, 8502105, datetime.time(10, 58), 'ch:1:sjyid:100001:19143-001'), (0, 8502105, datetime.time(10, 42), 'ch:1:sjyid:100001:8539-001'), (1, 8502119, datetime.time(10, 5), 'ch:1:sjyid:100001:19134-001'), (1, 8502106, datetime.time(10, 31), 'ch:1:sjyid:100001:19141-001'), (0, 8502105, datetime.time(10, 30), 'ch:1:sjyid:100001:19136-001'), (0, 8502105, datetime.time(10, 16), 'ch:1:sjyid:100001:8536-001'), (1, 8502247, datetime.time(10, 19), 'ch:1:sjyid:100001:8536-001'), (1, 8502119, datetime.time(10, 31), 'ch:1:sjyid:100001:8436-001'), (0, 8502105, datetime.time(10, 28), 'ch:1:sjyid:100001:19141-001'), (0, 8502105, datetime.time(10, 25), 'ch:1:sjyid:100001:8436-001')]
# '8502106': [(1, 8502105, datetime.time(11, 0), 'ch:1:sjyid:100001:19138-001'), (1, 8502105, datetime.time(10, 30), 'ch:1:sjyid:100001:19136-001'), (0, 8502106, datetime.time(10, 31), 'ch:1:sjyid:100001:19141-001'), (1, 8516219, datetime.time(10, 34), 'ch:1:sjyid:100001:19141-001'), (0, 8502106, datetime.time(10, 57), 'ch:1:sjyid:100001:19138-001'), (1, 8502105, datetime.time(10, 0), 'ch:1:sjyid:100001:19134-001'), (0, 8502106, datetime.time(10, 1), 'ch:1:sjyid:100001:19139-001'), (1, 8516219, datetime.time(10, 4), 'ch:1:sjyid:100001:19139-001'), (0, 8502106, datetime.time(10, 27), 'ch:1:sjyid:100001:19136-001')]
# '8502110': [(1, 8500218, datetime.time(10, 55), 'ch:1:sjyid:100001:8436-001'), (0, 8502110, datetime.time(10, 41), 'ch:1:sjyid:100001:8641-001'), (1, 8502111, datetime.time(10, 43), 'ch:1:sjyid:100001:8641-001'), (0, 8502110, datetime.time(10, 49), 'ch:1:sjyid:100001:8436-001'), (1, 8502111, datetime.time(10, 11), 'ch:1:sjyid:100001:8437-001'), (0, 8502110, datetime.time(10, 16), 'ch:1:sjyid:100001:8636-001'), (1, 8500218, datetime.time(9, 55), 'ch:1:sjyid:100001:8432-001'), (0, 8502110, datetime.time(10, 9), 'ch:1:sjyid:100001:8437-001')]
# '8502111': [(1, 8502110, datetime.time(10, 49), 'ch:1:sjyid:100001:8436-001'), (1, 8502110, datetime.time(10, 16), 'ch:1:sjyid:100001:8636-001'), (1, 8502112, datetime.time(10, 46), 'ch:1:sjyid:100001:8641-001'), (0, 8502111, datetime.time(10, 46), 'ch:1:sjyid:100001:8436-001'), (0, 8502111, datetime.time(10, 43), 'ch:1:sjyid:100001:8641-001'), (1, 8502112, datetime.time(10, 14), 'ch:1:sjyid:100001:8437-001'), (0, 8502111, datetime.time(10, 13), 'ch:1:sjyid:100001:8636-001'), (1, 8502110, datetime.time(9, 49), 'ch:1:sjyid:100001:8432-001'), (0, 8502111, datetime.time(10, 11), 'ch:1:sjyid:100001:8437-001')]
# '8502112': [(1, 8502111, datetime.time(10, 46), 'ch:1:sjyid:100001:8436-001'), (0, 8502112, datetime.time(10, 46), 'ch:1:sjyid:100001:8641-001'), (1, 8502113, datetime.time(10, 50), 'ch:1:sjyid:100001:8641-001'), (1, 8502111, datetime.time(10, 13), 'ch:1:sjyid:100001:8636-001'), (0, 8502112, datetime.time(10, 14), 'ch:1:sjyid:100001:8437-001'), (1, 8502113, datetime.time(10, 18), 'ch:1:sjyid:100001:8437-001'), (0, 8502112, datetime.time(10, 44), 'ch:1:sjyid:100001:8436-001'), (1, 8502111, datetime.time(9, 46), 'ch:1:sjyid:100001:8432-001'), (0, 8502112, datetime.time(9, 46), 'ch:1:sjyid:100001:8637-001'), (1, 8502113, datetime.time(9, 50), 'ch:1:sjyid:100001:8637-001'), (0, 8502112, datetime.time(10, 11), 'ch:1:sjyid:100001:8636-001')]
# '8502113': [(1, 8500218, datetime.time(10, 40), 'ch:1:sjyid:100001:516-001'), (0, 8502113, datetime.time(10, 31), 'ch:1:sjyid:100001:515-001'), (0, 8502113, datetime.time(10, 34), 'ch:1:sjyid:100001:8939-001'), (1, 8502114, datetime.time(10, 38), 'ch:1:sjyid:100001:8939-001'), (0, 8502113, datetime.time(10, 36), 'ch:1:sjyid:100001:2262-001'), (1, 8500026, datetime.time(10, 55), 'ch:1:sjyid:100001:2262-001'), (0, 8502113, datetime.time(10, 40), 'ch:1:sjyid:100001:8436-001'), (1, 8502112, datetime.time(10, 44), 'ch:1:sjyid:100001:8436-001'), (0, 8502113, datetime.time(10, 58), 'ch:1:sjyid:100001:8941-001'), (0, 8502113, datetime.time(10, 45), 'ch:1:sjyid:100001:4767-001'), (1, 8502115, datetime.time(10, 52), 'ch:1:sjyid:100001:4767-001'), (0, 8502113, datetime.time(10, 46), 'ch:1:sjyid:100001:2166-001'), (1, 8500218, datetime.time(10, 56), 'ch:1:sjyid:100001:2166-001'), (0, 8502113, datetime.time(10, 50), 'ch:1:sjyid:100001:8641-001'), (0, 8502113, datetime.time(10, 14), 'ch:1:sjyid:100001:2167-001'), (1, 8500309, datetime.time(10, 30), 'ch:1:sjyid:100001:2167-001'), (0, 8502113, datetime.time(10, 18), 'ch:1:sjyid:100001:8437-001'), (1, 8502114, datetime.time(10, 23), 'ch:1:sjyid:100001:8437-001'), (0, 8502113, datetime.time(10, 23), 'ch:1:sjyid:100001:2265-001'), (1, 8502119, datetime.time(10, 31), 'ch:1:sjyid:100001:2265-001'), (0, 8502113, datetime.time(10, 26), 'ch:1:sjyid:100001:8936-001'), (1, 8500218, datetime.time(10, 36), 'ch:1:sjyid:100001:8936-001'), (0, 8502113, datetime.time(10, 30), 'ch:1:sjyid:100001:516-001'), (1, 8500218, datetime.time(10, 12), 'ch:1:sjyid:100001:8934-001'), (0, 8502113, datetime.time(10, 8), 'ch:1:sjyid:100001:8636-001'), (1, 8502112, datetime.time(10, 11), 'ch:1:sjyid:100001:8636-001'), (0, 8502113, datetime.time(10, 13), 'ch:1:sjyid:100001:4764-001'), (1, 8500218, datetime.time(9, 40), 'ch:1:sjyid:100001:514-003'), (1, 8502114, datetime.time(10, 2), 'ch:1:sjyid:100001:8937-001'), (0, 8502113, datetime.time(10, 1), 'ch:1:sjyid:100001:8934-001'), (0, 8502113, datetime.time(9, 31), 'ch:1:sjyid:100001:513-001'), (1, 8503000, datetime.time(10, 3), 'ch:1:sjyid:100001:513-001'), (0, 8502113, datetime.time(9, 34), 'ch:1:sjyid:100001:8935-001'), (1, 8502114, datetime.time(9, 38), 'ch:1:sjyid:100001:8935-001'), (0, 8502113, datetime.time(9, 36), 'ch:1:sjyid:100001:2260-001'), (1, 8500026, datetime.time(9, 55), 'ch:1:sjyid:100001:2260-001'), (0, 8502113, datetime.time(9, 40), 'ch:1:sjyid:100001:8432-001'), (1, 8502112, datetime.time(9, 44), 'ch:1:sjyid:100001:8432-001'), (1, 8502119, datetime.time(10, 1), 'ch:1:sjyid:100001:8637-001'), (0, 8502113, datetime.time(9, 58), 'ch:1:sjyid:100001:8937-001'), (0, 8502113, datetime.time(9, 45), 'ch:1:sjyid:100001:4765-001'), (1, 8502115, datetime.time(9, 52), 'ch:1:sjyid:100001:4765-001'), (0, 8502113, datetime.time(9, 46), 'ch:1:sjyid:100001:2164-001'), (1, 8500218, datetime.time(9, 56), 'ch:1:sjyid:100001:2164-001'), (0, 8502113, datetime.time(9, 50), 'ch:1:sjyid:100001:8637-001')]
# '8502114': [(1, 8502115, datetime.time(10, 42), 'ch:1:sjyid:100001:8939-001'), (0, 8502114, datetime.time(10, 55), 'ch:1:sjyid:100001:8938-001'), (1, 8502113, datetime.time(10, 40), 'ch:1:sjyid:100001:8436-001'), (0, 8502114, datetime.time(10, 38), 'ch:1:sjyid:100001:8939-001'), (1, 8502119, datetime.time(10, 29), 'ch:1:sjyid:100001:8437-001'), (0, 8502114, datetime.time(10, 34), 'ch:1:sjyid:100001:8436-001'), (1, 8502113, datetime.time(10, 26), 'ch:1:sjyid:100001:8936-001'), (0, 8502114, datetime.time(10, 23), 'ch:1:sjyid:100001:8437-001'), (1, 8502113, datetime.time(10, 1), 'ch:1:sjyid:100001:8934-001'), (0, 8502114, datetime.time(10, 2), 'ch:1:sjyid:100001:8937-001'), (1, 8502115, datetime.time(10, 6), 'ch:1:sjyid:100001:8937-001'), (0, 8502114, datetime.time(10, 20), 'ch:1:sjyid:100001:8936-001'), (1, 8502115, datetime.time(9, 42), 'ch:1:sjyid:100001:8935-001'), (0, 8502114, datetime.time(9, 55), 'ch:1:sjyid:100001:8934-001')]
# '8502115': [(1, 8502114, datetime.time(10, 55), 'ch:1:sjyid:100001:8938-001'), (1, 8502128, datetime.time(10, 44), 'ch:1:sjyid:100001:8939-001'), (0, 8502115, datetime.time(10, 52), 'ch:1:sjyid:100001:4767-001'), (0, 8502115, datetime.time(10, 52), 'ch:1:sjyid:100001:8938-001'), (1, 8502113, datetime.time(10, 13), 'ch:1:sjyid:100001:4764-001'), (0, 8502115, datetime.time(10, 17), 'ch:1:sjyid:100001:8936-001'), (1, 8502114, datetime.time(10, 20), 'ch:1:sjyid:100001:8936-001'), (0, 8502115, datetime.time(10, 42), 'ch:1:sjyid:100001:8939-001'), (1, 8502114, datetime.time(9, 55), 'ch:1:sjyid:100001:8934-001'), (1, 8502128, datetime.time(10, 8), 'ch:1:sjyid:100001:8937-001'), (0, 8502115, datetime.time(10, 7), 'ch:1:sjyid:100001:4764-001'), (0, 8502115, datetime.time(10, 6), 'ch:1:sjyid:100001:8937-001'), (1, 8502128, datetime.time(9, 44), 'ch:1:sjyid:100001:8935-001'), (0, 8502115, datetime.time(9, 52), 'ch:1:sjyid:100001:4765-001'), (1, 8500309, datetime.time(10, 3), 'ch:1:sjyid:100001:4765-001'), (0, 8502115, datetime.time(9, 52), 'ch:1:sjyid:100001:8934-001')]
# '8502116': [(1, 8502128, datetime.time(10, 49), 'ch:1:sjyid:100001:8938-001'), (1, 8500309, datetime.time(10, 52), 'ch:1:sjyid:100001:8939-001'), (0, 8502116, datetime.time(10, 47), 'ch:1:sjyid:100001:8938-001'), (1, 8502128, datetime.time(10, 14), 'ch:1:sjyid:100001:8936-001'), (0, 8502116, datetime.time(10, 46), 'ch:1:sjyid:100001:8939-001'), (1, 8502128, datetime.time(9, 49), 'ch:1:sjyid:100001:8934-001'), (1, 8500309, datetime.time(10, 22), 'ch:1:sjyid:100001:8937-001'), (0, 8502116, datetime.time(10, 11), 'ch:1:sjyid:100001:8936-001'), (0, 8502116, datetime.time(10, 10), 'ch:1:sjyid:100001:8937-001'), (1, 8500309, datetime.time(9, 52), 'ch:1:sjyid:100001:8935-001'), (0, 8502116, datetime.time(9, 47), 'ch:1:sjyid:100001:8934-001')]
# '8502119': [(0, 8502119, datetime.time(10, 55), 'ch:1:sjyid:100001:19143-001'), (1, 8502105, datetime.time(10, 58), 'ch:1:sjyid:100001:19143-001'), (0, 8502119, datetime.time(10, 58), 'ch:1:sjyid:100001:4816-001'), (0, 8502119, datetime.time(11, 0), 'ch:1:sjyid:100001:8640-001'), (0, 8502119, datetime.time(10, 25), 'ch:1:sjyid:100001:19141-001'), (1, 8502105, datetime.time(10, 28), 'ch:1:sjyid:100001:19141-001'), (0, 8502119, datetime.time(10, 29), 'ch:1:sjyid:100001:2262-001'), (1, 8502113, datetime.time(10, 36), 'ch:1:sjyid:100001:2262-001'), (0, 8502119, datetime.time(10, 31), 'ch:1:sjyid:100001:2265-001'), (0, 8502119, datetime.time(10, 35), 'ch:1:sjyid:100001:19136-001'), (0, 8502119, datetime.time(10, 31), 'ch:1:sjyid:100001:8436-001'), (1, 8502114, datetime.time(10, 34), 'ch:1:sjyid:100001:8436-001'), (0, 8502119, datetime.time(10, 29), 'ch:1:sjyid:100001:8437-001'), (1, 8502105, datetime.time(10, 34), 'ch:1:sjyid:100001:8437-001'), (1, 8502211, datetime.time(10, 4), 'ch:1:sjyid:100001:8637-001'), (0, 8502119, datetime.time(10, 2), 'ch:1:sjyid:100001:4815-001'), (0, 8502119, datetime.time(10, 5), 'ch:1:sjyid:100001:19134-001')]
# '8502128': [(1, 8502115, datetime.time(10, 52), 'ch:1:sjyid:100001:8938-001'), (1, 8502116, datetime.time(10, 46), 'ch:1:sjyid:100001:8939-001'), (0, 8502128, datetime.time(10, 49), 'ch:1:sjyid:100001:8938-001'), (1, 8502115, datetime.time(10, 17), 'ch:1:sjyid:100001:8936-001'), (0, 8502128, datetime.time(10, 44), 'ch:1:sjyid:100001:8939-001'), (1, 8502115, datetime.time(9, 52), 'ch:1:sjyid:100001:8934-001'), (1, 8502116, datetime.time(10, 10), 'ch:1:sjyid:100001:8937-001'), (0, 8502128, datetime.time(10, 14), 'ch:1:sjyid:100001:8936-001'), (0, 8502128, datetime.time(10, 8), 'ch:1:sjyid:100001:8937-001'), (1, 8502116, datetime.time(9, 46), 'ch:1:sjyid:100001:8935-001'), (0, 8502128, datetime.time(9, 49), 'ch:1:sjyid:100001:8934-001')]
# '8502200': [(1, 8505000, datetime.time(10, 44), 'ch:1:sjyid:100001:21131-001'), (1, 8516350, datetime.time(11, 0), 'ch:1:sjyid:100001:21132-001'), (0, 8502200, datetime.time(10, 59), 'ch:1:sjyid:100001:21133-001'), (0, 8502200, datetime.time(10, 31), 'ch:1:sjyid:100001:21130-001'), (1, 8516350, datetime.time(10, 32), 'ch:1:sjyid:100001:21130-001'), (0, 8502200, datetime.time(10, 58), 'ch:1:sjyid:100001:21132-001')]
# '8502201': [(1, 8515997, datetime.time(10, 21), 'ch:1:sjyid:100001:21131-001'), (1, 8502202, datetime.time(10, 51), 'ch:1:sjyid:100001:21130-001'), (0, 8502201, datetime.time(10, 52), 'ch:1:sjyid:100001:21133-001'), (1, 8515997, datetime.time(10, 54), 'ch:1:sjyid:100001:21133-001'), (0, 8502201, datetime.time(10, 37), 'ch:1:sjyid:100001:21130-001')]
# '8502202': [(0, 8502202, datetime.time(10, 16), 'ch:1:sjyid:100001:21131-001'), (1, 8502201, datetime.time(10, 18), 'ch:1:sjyid:100001:21131-001'), (1, 8502203, datetime.time(10, 57), 'ch:1:sjyid:100001:21130-001'), (0, 8502202, datetime.time(10, 49), 'ch:1:sjyid:100001:21133-001'), (1, 8502201, datetime.time(10, 52), 'ch:1:sjyid:100001:21133-001'), (0, 8502202, datetime.time(10, 51), 'ch:1:sjyid:100001:21130-001'), (0, 8502202, datetime.time(10, 49), 'ch:1:sjyid:100001:2217-001'), (1, 8502204, datetime.time(10, 58), 'ch:1:sjyid:100001:2217-001')]
# '8502203': [(1, 8515995, datetime.time(10, 58), 'ch:1:sjyid:100001:21130-001'), (0, 8502203, datetime.time(10, 59), 'ch:1:sjyid:100001:21135-001'), (0, 8502203, datetime.time(10, 29), 'ch:1:sjyid:100001:22128-001'), (1, 8515995, datetime.time(10, 30), 'ch:1:sjyid:100001:22128-001'), (1, 8515996, datetime.time(10, 44), 'ch:1:sjyid:100001:21133-001'), (0, 8502203, datetime.time(10, 44), 'ch:1:sjyid:100001:22130-001'), (1, 8515995, datetime.time(10, 45), 'ch:1:sjyid:100001:22130-001'), (0, 8502203, datetime.time(10, 57), 'ch:1:sjyid:100001:21130-001'), (0, 8502203, datetime.time(10, 43), 'ch:1:sjyid:100001:21133-001'), (1, 8515996, datetime.time(10, 14), 'ch:1:sjyid:100001:22131-001'), (0, 8502203, datetime.time(10, 14), 'ch:1:sjyid:100001:21128-001'), (1, 8515995, datetime.time(10, 15), 'ch:1:sjyid:100001:21128-001'), (0, 8502203, datetime.time(10, 27), 'ch:1:sjyid:100001:22133-001')]
# '8502204': [(1, 8502202, datetime.time(10, 11), 'ch:1:sjyid:100001:2212-001'), (0, 8502204, datetime.time(11, 0), 'ch:1:sjyid:100001:327-001'), (0, 8502204, datetime.time(10, 5), 'ch:1:sjyid:100001:21126-001'), (1, 8515993, datetime.time(10, 6), 'ch:1:sjyid:100001:21126-001'), (1, 8516187, datetime.time(10, 21), 'ch:1:sjyid:100001:22133-001'), (1, 8515993, datetime.time(10, 38), 'ch:1:sjyid:100001:22128-001'), (1, 8516187, datetime.time(10, 53), 'ch:1:sjyid:100001:21135-001'), (0, 8502204, datetime.time(10, 53), 'ch:1:sjyid:100001:21238-001'), (0, 8502204, datetime.time(10, 58), 'ch:1:sjyid:100001:2217-001'), (0, 8502204, datetime.time(10, 51), 'ch:1:sjyid:100001:22130-001'), (1, 8515993, datetime.time(10, 53), 'ch:1:sjyid:100001:22130-001'), (0, 8502204, datetime.time(10, 52), 'ch:1:sjyid:100001:21135-001'), (0, 8502204, datetime.time(10, 22), 'ch:1:sjyid:100001:21128-001'), (1, 8515993, datetime.time(10, 23), 'ch:1:sjyid:100001:21128-001'), (1, 8516187, datetime.time(10, 37), 'ch:1:sjyid:100001:21133-001'), (0, 8502204, datetime.time(10, 37), 'ch:1:sjyid:100001:21237-001'), (1, 8502231, datetime.time(10, 44), 'ch:1:sjyid:100001:21237-001'), (0, 8502204, datetime.time(10, 37), 'ch:1:sjyid:100001:22128-001'), (0, 8502204, datetime.time(10, 23), 'ch:1:sjyid:100001:21236-001'), (0, 8502204, datetime.time(10, 29), 'ch:1:sjyid:100001:2618-001'), (0, 8502204, datetime.time(10, 30), 'ch:1:sjyid:100061:2417-001'), (1, 8505004, datetime.time(10, 54), 'ch:1:sjyid:100061:2417-001'), (0, 8502204, datetime.time(10, 31), 'ch:1:sjyid:100001:870-001'), (0, 8502204, datetime.time(10, 32), 'ch:1:sjyid:100001:2619-001'), (0, 8502204, datetime.time(10, 36), 'ch:1:sjyid:100001:21133-001'), (0, 8502204, datetime.time(10, 6), 'ch:1:sjyid:100001:22131-001'), (1, 8516187, datetime.time(10, 7), 'ch:1:sjyid:100001:22131-001'), (0, 8502204, datetime.time(10, 7), 'ch:1:sjyid:100001:21235-001'), (1, 8502231, datetime.time(10, 13), 'ch:1:sjyid:100001:21235-001'), (0, 8502204, datetime.time(10, 20), 'ch:1:sjyid:100001:22133-001')]
# '8502205': [(1, 8505004, datetime.time(10, 28), 'ch:1:sjyid:100001:21235-001'), (1, 8517112, datetime.time(10, 40), 'ch:1:sjyid:100001:21238-001'), (0, 8502205, datetime.time(10, 38), 'ch:1:sjyid:100001:21238-001')]
# '8502206': [(0, 8502206, datetime.time(10, 58), 'ch:1:sjyid:100001:2214-001'), (0, 8502206, datetime.time(10, 37), 'ch:1:sjyid:100001:20240-001'), (1, 8502208, datetime.time(10, 45), 'ch:1:sjyid:100001:20240-001'), (0, 8502206, datetime.time(10, 52), 'ch:1:sjyid:100001:20237-001'), (0, 8502206, datetime.time(9, 58), 'ch:1:sjyid:100001:2212-001'), (1, 8502204, datetime.time(10, 3), 'ch:1:sjyid:100001:2212-001'), (0, 8502206, datetime.time(10, 1), 'ch:1:sjyid:100001:2215-001'), (1, 8503202, datetime.time(10, 14), 'ch:1:sjyid:100001:2215-001'), (0, 8502206, datetime.time(10, 7), 'ch:1:sjyid:100001:20238-002'), (1, 8502208, datetime.time(10, 15), 'ch:1:sjyid:100001:20238-002'), (0, 8502206, datetime.time(10, 22), 'ch:1:sjyid:100001:20235-001')]
# '8502208': [(1, 8502206, datetime.time(10, 52), 'ch:1:sjyid:100001:20237-001'), (0, 8502208, datetime.time(10, 45), 'ch:1:sjyid:100001:20240-001'), (1, 8502209, datetime.time(10, 47), 'ch:1:sjyid:100001:20240-001'), (1, 8502206, datetime.time(10, 22), 'ch:1:sjyid:100001:20235-001'), (0, 8502208, datetime.time(10, 15), 'ch:1:sjyid:100001:20238-002'), (1, 8502209, datetime.time(10, 17), 'ch:1:sjyid:100001:20238-002'), (0, 8502208, datetime.time(10, 44), 'ch:1:sjyid:100001:20237-001'), (1, 8502206, datetime.time(9, 52), 'ch:1:sjyid:100001:20233-001'), (0, 8502208, datetime.time(9, 45), 'ch:1:sjyid:100001:20236-001'), (1, 8502209, datetime.time(9, 47), 'ch:1:sjyid:100001:20236-001'), (0, 8502208, datetime.time(10, 14), 'ch:1:sjyid:100001:20235-001')]
# '8502209': [(1, 8502208, datetime.time(10, 44), 'ch:1:sjyid:100001:20237-001'), (1, 8503202, datetime.time(10, 51), 'ch:1:sjyid:100001:20240-001'), (0, 8502209, datetime.time(10, 47), 'ch:1:sjyid:100001:20240-001'), (1, 8502208, datetime.time(10, 14), 'ch:1:sjyid:100001:20235-001'), (1, 8503202, datetime.time(10, 21), 'ch:1:sjyid:100001:20238-002'), (0, 8502209, datetime.time(10, 40), 'ch:1:sjyid:100001:20237-001'), (0, 8502209, datetime.time(10, 17), 'ch:1:sjyid:100001:20238-002'), (1, 8502208, datetime.time(9, 44), 'ch:1:sjyid:100001:20233-001'), (1, 8503202, datetime.time(9, 51), 'ch:1:sjyid:100001:20236-001'), (0, 8502209, datetime.time(10, 10), 'ch:1:sjyid:100001:20235-001'), (0, 8502209, datetime.time(9, 47), 'ch:1:sjyid:100001:20236-001')]
# '8502211': [(1, 8502212, datetime.time(10, 46), 'ch:1:sjyid:100001:8539-001'), (1, 8502119, datetime.time(11, 0), 'ch:1:sjyid:100001:8640-001'), (0, 8502211, datetime.time(10, 53), 'ch:1:sjyid:100001:8640-001'), (1, 8502212, datetime.time(10, 7), 'ch:1:sjyid:100001:8637-001'), (0, 8502211, datetime.time(10, 37), 'ch:1:sjyid:100001:8639-001'), (1, 8502212, datetime.time(10, 40), 'ch:1:sjyid:100001:8639-001'), (0, 8502211, datetime.time(10, 44), 'ch:1:sjyid:100001:8539-001'), (1, 8502105, datetime.time(10, 16), 'ch:1:sjyid:100001:8536-001'), (0, 8502211, datetime.time(10, 20), 'ch:1:sjyid:100001:8638-001'), (0, 8502211, datetime.time(10, 13), 'ch:1:sjyid:100001:8536-001')]
# '8502212': [(1, 8502213, datetime.time(10, 50), 'ch:1:sjyid:100001:8539-001'), (0, 8502212, datetime.time(10, 50), 'ch:1:sjyid:100001:8640-001'), (1, 8502211, datetime.time(10, 53), 'ch:1:sjyid:100001:8640-001'), (1, 8502213, datetime.time(10, 11), 'ch:1:sjyid:100001:8637-001'), (1, 8502211, datetime.time(10, 20), 'ch:1:sjyid:100001:8638-001'), (1, 8502213, datetime.time(10, 44), 'ch:1:sjyid:100001:8639-001'), (0, 8502212, datetime.time(10, 46), 'ch:1:sjyid:100001:8539-001'), (0, 8502212, datetime.time(10, 40), 'ch:1:sjyid:100001:8639-001'), (0, 8502212, datetime.time(10, 10), 'ch:1:sjyid:100001:8536-001'), (1, 8502211, datetime.time(10, 13), 'ch:1:sjyid:100001:8536-001'), (0, 8502212, datetime.time(10, 17), 'ch:1:sjyid:100001:8638-001')]
# '8502213': [(1, 8502214, datetime.time(10, 15), 'ch:1:sjyid:100001:8637-001'), (1, 8502212, datetime.time(10, 50), 'ch:1:sjyid:100001:8640-001'), (0, 8502213, datetime.time(10, 50), 'ch:1:sjyid:100001:8539-001'), (0, 8502213, datetime.time(10, 15), 'ch:1:sjyid:100001:8638-001'), (1, 8502212, datetime.time(10, 17), 'ch:1:sjyid:100001:8638-001'), (1, 8502214, datetime.time(10, 48), 'ch:1:sjyid:100001:8639-001'), (0, 8502213, datetime.time(10, 47), 'ch:1:sjyid:100001:8640-001'), (0, 8502213, datetime.time(10, 44), 'ch:1:sjyid:100001:8639-001')]
# '8502214': [(1, 8502215, datetime.time(10, 19), 'ch:1:sjyid:100001:8637-001'), (1, 8502213, datetime.time(10, 47), 'ch:1:sjyid:100001:8640-001'), (0, 8502214, datetime.time(10, 48), 'ch:1:sjyid:100001:8639-001'), (1, 8502215, datetime.time(10, 51), 'ch:1:sjyid:100001:8639-001'), (0, 8502214, datetime.time(10, 42), 'ch:1:sjyid:100001:8640-001')]
# '8502215': [(1, 8502216, datetime.time(10, 22), 'ch:1:sjyid:100001:8637-001'), (1, 8502214, datetime.time(10, 42), 'ch:1:sjyid:100001:8640-001'), (1, 8502218, datetime.time(10, 58), 'ch:1:sjyid:100001:8639-001'), (0, 8502215, datetime.time(10, 51), 'ch:1:sjyid:100001:8639-001'), (0, 8502215, datetime.time(10, 39), 'ch:1:sjyid:100001:8640-001')]
# '8502216': [(1, 8502217, datetime.time(10, 25), 'ch:1:sjyid:100001:8637-001'), (1, 8502215, datetime.time(10, 39), 'ch:1:sjyid:100001:8640-001'), (0, 8502216, datetime.time(10, 35), 'ch:1:sjyid:100001:8640-001')]
# '8502217': [(1, 8502218, datetime.time(10, 29), 'ch:1:sjyid:100001:8637-001'), (0, 8502217, datetime.time(10, 32), 'ch:1:sjyid:100001:8640-001'), (1, 8502216, datetime.time(10, 35), 'ch:1:sjyid:100001:8640-001')]
# '8502218': [(1, 8502219, datetime.time(10, 31), 'ch:1:sjyid:100001:8637-001'), (0, 8502218, datetime.time(10, 58), 'ch:1:sjyid:100001:8639-001'), (0, 8502218, datetime.time(10, 59), 'ch:1:sjyid:100001:8642-001')]
# '8502219': [(0, 8502219, datetime.time(10, 56), 'ch:1:sjyid:100001:8642-001'), (1, 8502218, datetime.time(10, 59), 'ch:1:sjyid:100001:8642-001')]
# ...
# '8508158': [(1, 8508157, datetime.time(10, 49), '85:81:428:000')]
# '8508159': [(1, 8508158, datetime.time(10, 48), '85:81:428:000')]
# '8508193': [(1, 8508152, datetime.time(11, 0), '85:81:428:000')]
# '8508200': [(1, 8508201, datetime.time(11, 0), 'ch:1:sjyid:100015:15239-001'), (1, 8508201, datetime.time(10, 29), 'ch:1:sjyid:100015:15237-001'), (0, 8508200, datetime.time(10, 32), 'ch:1:sjyid:100015:15238-001'), (1, 8507003, datetime.time(10, 37), 'ch:1:sjyid:100015:15238-001'), (0, 8508200, datetime.time(10, 56), 'ch:1:sjyid:100015:15239-001')]
# '8508201': [(1, 8508202, datetime.time(10, 34), 'ch:1:sjyid:100015:15237-001'), (0, 8508201, datetime.time(11, 0), 'ch:1:sjyid:100015:15239-001'), (0, 8508201, datetime.time(10, 57), 'ch:1:sjyid:100015:15240-001')]
# '8508202': [(1, 8508203, datetime.time(10, 37), 'ch:1:sjyid:100015:15237-001'), (1, 8508201, datetime.time(10, 57), 'ch:1:sjyid:100015:15240-001'), (0, 8508202, datetime.time(11, 0), 'ch:1:sjyid:100015:6416-001'), (0, 8508202, datetime.time(10, 36), 'ch:1:sjyid:100015:6618-002'), (1, 8508260, datetime.time(10, 40), 'ch:1:sjyid:100015:6618-002'), (0, 8508202, datetime.time(10, 52), 'ch:1:sjyid:100015:4367-001'), (0, 8508202, datetime.time(10, 55), 'ch:1:sjyid:100015:15240-001')]
# '8508203': [(1, 8508204, datetime.time(10, 40), 'ch:1:sjyid:100015:15237-001'), (1, 8508202, datetime.time(10, 55), 'ch:1:sjyid:100015:15240-001'), (0, 8508203, datetime.time(10, 49), 'ch:1:sjyid:100015:15240-001')]
# '8508204': [(1, 8508205, datetime.time(10, 44), 'ch:1:sjyid:100015:15237-001'), (0, 8508204, datetime.time(10, 46), 'ch:1:sjyid:100015:15240-001'), (1, 8508203, datetime.time(10, 49), 'ch:1:sjyid:100015:15240-001')]
# '8508205': [(1, 8508206, datetime.time(10, 47), 'ch:1:sjyid:100015:15237-001')]
# '8508260': [(1, 8508261, datetime.time(10, 43), 'ch:1:sjyid:100015:6618-002'), (0, 8508260, datetime.time(10, 54), 'ch:1:sjyid:100015:6417-001')]
# '8508261': [(1, 8508262, datetime.time(10, 47), 'ch:1:sjyid:100015:6618-002'), (0, 8508261, datetime.time(10, 51), 'ch:1:sjyid:100015:6417-001'), (1, 8508260, datetime.time(10, 54), 'ch:1:sjyid:100015:6417-001')]
# '8509002': [(0, 8509002, datetime.time(10, 48), 'ch:1:sjyid:100001:770-001'), (1, 8509411, datetime.time(10, 57), 'ch:1:sjyid:100001:770-001'), (0, 8509002, datetime.time(10, 48), 'ch:1:sjyid:100046:12239-001'), (0, 8509002, datetime.time(10, 38), 'ch:1:sjyid:100001:3259-002'), (0, 8509002, datetime.time(10, 39), 'ch:1:sjyid:100046:12238-001'), (1, 8509003, datetime.time(10, 42), 'ch:1:sjyid:100046:12238-001'), (0, 8509002, datetime.time(10, 42), 'ch:1:sjyid:100001:563-001')]
# '8509003': [(1, 8509004, datetime.time(10, 45), 'ch:1:sjyid:100046:12238-001'), (0, 8509003, datetime.time(10, 43), 'ch:1:sjyid:100046:12239-001'), (1, 8509002, datetime.time(10, 48), 'ch:1:sjyid:100046:12239-001')]
# '8509004': [(1, 8509002, datetime.time(10, 34), 'ch:1:sjyid:100001:2361-007'), (0, 8509004, datetime.time(10, 30), 'ch:1:sjyid:100061:2366-006'), (1, 8509411, datetime.time(10, 35), 'ch:1:sjyid:100061:2366-006'), (0, 8509004, datetime.time(10, 33), 'ch:1:sjyid:100001:3259-002'), (1, 8509002, datetime.time(10, 38), 'ch:1:sjyid:100001:3259-002'), (0, 8509004, datetime.time(10, 41), 'ch:1:sjyid:100046:12239-001'), (1, 8509003, datetime.time(10, 43), 'ch:1:sjyid:100046:12239-001'), (0, 8509004, datetime.time(10, 45), 'ch:1:sjyid:100046:12238-001')]
# '8509404': [(0, 8509404, datetime.time(10, 47), 'ch:1:sjyid:100061:11435-002'), (1, 8509406, datetime.time(10, 50), 'ch:1:sjyid:100061:11435-002')]
# '8509411': [(1, 8509002, datetime.time(10, 42), 'ch:1:sjyid:100001:563-001'), (0, 8509411, datetime.time(10, 35), 'ch:1:sjyid:100001:3266-002'), (1, 8509404, datetime.time(10, 45), 'ch:1:sjyid:100001:3266-002'), (0, 8509411, datetime.time(10, 57), 'ch:1:sjyid:100001:770-001'), (0, 8509411, datetime.time(10, 35), 'ch:1:sjyid:100061:2366-006'), (1, 8509414, datetime.time(10, 44), 'ch:1:sjyid:100061:2366-006'), (1, 8509004, datetime.time(10, 28), 'ch:1:sjyid:100001:2361-007'), (0, 8509411, datetime.time(10, 27), 'ch:1:sjyid:100001:3259-002'), (1, 8509004, datetime.time(10, 33), 'ch:1:sjyid:100001:3259-002'), (0, 8509411, datetime.time(10, 33), 'ch:1:sjyid:100001:563-001'), (0, 8509411, datetime.time(10, 27), 'ch:1:sjyid:100001:566-001')]
# '8509413': [(1, 8509412, datetime.time(10, 54), 'ch:1:sjyid:100061:11441-001')]
# '8509414': [(1, 8503225, datetime.time(11, 0), 'ch:1:sjyid:100061:2366-006'), (0, 8509414, datetime.time(10, 46), 'ch:1:sjyid:100061:11441-001'), (1, 8509413, datetime.time(10, 49), 'ch:1:sjyid:100061:11441-001'), (1, 8509411, datetime.time(10, 23), 'ch:1:sjyid:100001:2361-007'), (0, 8509414, datetime.time(10, 44), 'ch:1:sjyid:100061:2366-006')]
# '8509416': [(1, 8509414, datetime.time(10, 46), 'ch:1:sjyid:100061:11441-001')]
# '8509417': [(1, 8509416, datetime.time(10, 41), 'ch:1:sjyid:100061:11441-001')]
# '8509418': [(1, 8509417, datetime.time(10, 37), 'ch:1:sjyid:100061:11441-001')]
# '8515992': [(0, 8515992, datetime.time(10, 16), 'ch:1:sjyid:100001:22133-001'), (1, 8515993, datetime.time(10, 17), 'ch:1:sjyid:100001:22133-001'), (0, 8515992, datetime.time(10, 48), 'ch:1:sjyid:100001:21135-001'), (1, 8515993, datetime.time(10, 49), 'ch:1:sjyid:100001:21135-001'), (0, 8515992, datetime.time(10, 54), 'ch:1:sjyid:100001:22130-001'), (0, 8515992, datetime.time(10, 32), 'ch:1:sjyid:100001:21133-001'), (1, 8515993, datetime.time(10, 34), 'ch:1:sjyid:100001:21133-001'), (0, 8515992, datetime.time(10, 40), 'ch:1:sjyid:100001:22128-001'), (0, 8515992, datetime.time(10, 24), 'ch:1:sjyid:100001:21128-001')]
# '8515993': [(1, 8515992, datetime.time(10, 7), 'ch:1:sjyid:100001:21126-001'), (1, 8502204, datetime.time(10, 20), 'ch:1:sjyid:100001:22133-001'), (1, 8515992, datetime.time(10, 40), 'ch:1:sjyid:100001:22128-001'), (1, 8502204, datetime.time(10, 52), 'ch:1:sjyid:100001:21135-001'), (0, 8515993, datetime.time(10, 53), 'ch:1:sjyid:100001:22130-001'), (1, 8515992, datetime.time(10, 54), 'ch:1:sjyid:100001:22130-001'), (0, 8515993, datetime.time(10, 49), 'ch:1:sjyid:100001:21135-001'), (1, 8515992, datetime.time(10, 24), 'ch:1:sjyid:100001:21128-001'), (1, 8502204, datetime.time(10, 36), 'ch:1:sjyid:100001:21133-001'), (0, 8515993, datetime.time(10, 38), 'ch:1:sjyid:100001:22128-001'), (0, 8515993, datetime.time(10, 34), 'ch:1:sjyid:100001:21133-001'), (0, 8515993, datetime.time(10, 23), 'ch:1:sjyid:100001:21128-001'), (0, 8515993, datetime.time(10, 17), 'ch:1:sjyid:100001:22133-001')]
# '8515995': [(1, 8502230, datetime.time(11, 0), 'ch:1:sjyid:100001:21130-001'), (1, 8502203, datetime.time(10, 27), 'ch:1:sjyid:100001:22133-001'), (1, 8502230, datetime.time(10, 32), 'ch:1:sjyid:100001:22128-001'), (1, 8502203, datetime.time(10, 59), 'ch:1:sjyid:100001:21135-001'), (0, 8515995, datetime.time(10, 58), 'ch:1:sjyid:100001:21130-001'), (1, 8502203, datetime.time(10, 43), 'ch:1:sjyid:100001:21133-001'), (1, 8502230, datetime.time(10, 47), 'ch:1:sjyid:100001:22130-001'), (0, 8515995, datetime.time(10, 57), 'ch:1:sjyid:100001:21135-001'), (0, 8515995, datetime.time(10, 45), 'ch:1:sjyid:100001:22130-001'), (0, 8515995, datetime.time(10, 41), 'ch:1:sjyid:100001:21133-001'), (0, 8515995, datetime.time(10, 30), 'ch:1:sjyid:100001:22128-001'), (1, 8502203, datetime.time(10, 13), 'ch:1:sjyid:100001:22131-001'), (1, 8502230, datetime.time(10, 17), 'ch:1:sjyid:100001:21128-001'), (0, 8515995, datetime.time(10, 25), 'ch:1:sjyid:100001:22133-001'), (0, 8515995, datetime.time(10, 15), 'ch:1:sjyid:100001:21128-001')]
# '8515996': [(1, 8502202, datetime.time(10, 49), 'ch:1:sjyid:100001:21133-001'), (0, 8515996, datetime.time(10, 44), 'ch:1:sjyid:100001:21133-001')]
# '8515997': [(1, 8516350, datetime.time(10, 23), 'ch:1:sjyid:100001:21131-001'), (1, 8502201, datetime.time(10, 37), 'ch:1:sjyid:100001:21130-001'), (1, 8516350, datetime.time(10, 56), 'ch:1:sjyid:100001:21133-001'), (0, 8515997, datetime.time(10, 54), 'ch:1:sjyid:100001:21133-001'), (0, 8515997, datetime.time(10, 34), 'ch:1:sjyid:100001:21130-001')]
# '8516161': [(1, 8507002, datetime.time(10, 48), 'ch:1:sjyid:100015:15239-001'), (0, 8516161, datetime.time(10, 49), 'ch:1:sjyid:100015:15137-001'), (1, 8507002, datetime.time(10, 52), 'ch:1:sjyid:100015:15137-001'), (0, 8516161, datetime.time(10, 53), 'ch:1:sjyid:100015:16437-001'), (0, 8516161, datetime.time(10, 54), 'ch:1:sjyid:100015:15338-001'), (0, 8516161, datetime.time(10, 49), 'ch:1:sjyid:100015:16339-001'), (1, 8504410, datetime.time(10, 54), 'ch:1:sjyid:100015:16339-001'), (1, 8504410, datetime.time(10, 24), 'ch:1:sjyid:100015:16337-001'), (1, 8507000, datetime.time(10, 42), 'ch:1:sjyid:100015:15434-001'), (0, 8516161, datetime.time(10, 38), 'ch:1:sjyid:100015:15136-001'), (1, 8507000, datetime.time(10, 45), 'ch:1:sjyid:100015:15136-001'), (0, 8516161, datetime.time(10, 39), 'ch:1:sjyid:100015:16336-001'), (1, 8507000, datetime.time(10, 47), 'ch:1:sjyid:100015:16336-001'), (0, 8516161, datetime.time(10, 43), 'ch:1:sjyid:100015:15238-001'), (1, 8507000, datetime.time(10, 50), 'ch:1:sjyid:100015:15238-001'), (0, 8516161, datetime.time(10, 45), 'ch:1:sjyid:100015:15239-001'), (0, 8516161, datetime.time(10, 23), 'ch:1:sjyid:100015:15435-001'), (1, 8504410, datetime.time(10, 27), 'ch:1:sjyid:100015:15435-001'), (0, 8516161, datetime.time(10, 24), 'ch:1:sjyid:100015:15336-001'), (1, 8507000, datetime.time(10, 32), 'ch:1:sjyid:100015:15336-001'), (0, 8516161, datetime.time(10, 33), 'ch:1:sjyid:100015:15339-001'), (1, 8504410, datetime.time(10, 38), 'ch:1:sjyid:100015:15339-001'), (0, 8516161, datetime.time(10, 35), 'ch:1:sjyid:100015:15434-001'), (1, 8507002, datetime.time(10, 22), 'ch:1:sjyid:100015:15135-001'), (1, 8507002, datetime.time(10, 18), 'ch:1:sjyid:100015:15237-001'), (0, 8516161, datetime.time(10, 19), 'ch:1:sjyid:100015:15135-001'), (0, 8516161, datetime.time(10, 19), 'ch:1:sjyid:100015:16337-001')]
# '8516176': [(1, 8500329, datetime.time(10, 46), 'ch:1:sjyid:100001:8734-001'), (0, 8516176, datetime.time(10, 46), 'ch:1:sjyid:100001:20743-001'), (1, 8503501, datetime.time(10, 49), 'ch:1:sjyid:100001:20743-001'), (0, 8516176, datetime.time(10, 16), 'ch:1:sjyid:100001:8741-001'), (1, 8503501, datetime.time(10, 19), 'ch:1:sjyid:100001:8741-001'), (0, 8516176, datetime.time(10, 39), 'ch:1:sjyid:100001:8734-001')]
# '8516187': [(1, 8502230, datetime.time(10, 23), 'ch:1:sjyid:100001:22133-001'), (1, 8502204, datetime.time(10, 37), 'ch:1:sjyid:100001:22128-001'), (1, 8502230, datetime.time(10, 55), 'ch:1:sjyid:100001:21135-001'), (0, 8516187, datetime.time(10, 37), 'ch:1:sjyid:100001:21133-001'), (1, 8502230, datetime.time(10, 39), 'ch:1:sjyid:100001:21133-001'), (1, 8502204, datetime.time(10, 51), 'ch:1:sjyid:100001:22130-001'), (0, 8516187, datetime.time(10, 53), 'ch:1:sjyid:100001:21135-001'), (0, 8516187, datetime.time(10, 49), 'ch:1:sjyid:100001:22130-001'), (0, 8516187, datetime.time(10, 34), 'ch:1:sjyid:100001:22128-001'), (1, 8502230, datetime.time(10, 9), 'ch:1:sjyid:100001:22131-001'), (1, 8502204, datetime.time(10, 22), 'ch:1:sjyid:100001:21128-001'), (0, 8516187, datetime.time(10, 21), 'ch:1:sjyid:100001:22133-001'), (0, 8516187, datetime.time(10, 19), 'ch:1:sjyid:100001:21128-001')]
# '8516218': [(1, 8506015, datetime.time(10, 19), 'ch:1:sjyid:100001:19235-001'), (1, 8506001, datetime.time(10, 44), 'ch:1:sjyid:100001:19240-001'), (0, 8516218, datetime.time(10, 46), 'ch:1:sjyid:100046:8137-001'), (1, 8506015, datetime.time(10, 49), 'ch:1:sjyid:100046:8137-001'), (0, 8516218, datetime.time(10, 41), 'ch:1:sjyid:100001:19240-001')]
# '8516219': [(1, 8502106, datetime.time(10, 57), 'ch:1:sjyid:100001:19138-001'), (1, 8502106, datetime.time(10, 27), 'ch:1:sjyid:100001:19136-001'), (1, 8503506, datetime.time(10, 39), 'ch:1:sjyid:100001:19141-001'), (0, 8516219, datetime.time(10, 54), 'ch:1:sjyid:100001:19138-001'), (0, 8516219, datetime.time(10, 34), 'ch:1:sjyid:100001:19141-001'), (1, 8502106, datetime.time(9, 57), 'ch:1:sjyid:100001:19134-001'), (1, 8503506, datetime.time(10, 9), 'ch:1:sjyid:100001:19139-001'), (0, 8516219, datetime.time(10, 24), 'ch:1:sjyid:100001:19136-001'), (0, 8516219, datetime.time(10, 4), 'ch:1:sjyid:100001:19139-001')]
# '8516270': [(1, 8506308, datetime.time(10, 55), 'ch:1:sjyid:100046:11739-001')]
# '8516271': [(1, 8506307, datetime.time(11, 0), 'ch:1:sjyid:100046:11739-001')]
# '8516350': [(1, 8502200, datetime.time(10, 27), 'ch:1:sjyid:100001:21131-001'), (1, 8515997, datetime.time(10, 34), 'ch:1:sjyid:100001:21130-001'), (1, 8502200, datetime.time(10, 59), 'ch:1:sjyid:100001:21133-001'), (0, 8516350, datetime.time(11, 0), 'ch:1:sjyid:100001:21132-001'), (0, 8516350, datetime.time(10, 56), 'ch:1:sjyid:100001:21133-001'), (0, 8516350, datetime.time(10, 32), 'ch:1:sjyid:100001:21130-001')]
# '8517112': [(1, 8502205, datetime.time(10, 22), 'ch:1:sjyid:100001:21235-001'), (1, 8502231, datetime.time(10, 45), 'ch:1:sjyid:100001:21238-001'), (0, 8517112, datetime.time(10, 49), 'ch:1:sjyid:100001:21237-001'), (0, 8517112, datetime.time(10, 40), 'ch:1:sjyid:100001:21238-001')]
# '8517131': [(0, 8517131, datetime.time(11, 0), 'ch:1:sjyid:100001:17239-002'), (1, 8500300, datetime.time(10, 32), 'ch:1:sjyid:100001:17137-001'), (0, 8517131, datetime.time(10, 58), 'ch:1:sjyid:100001:17238-002')]
# '8518100': [(1, 8506361, datetime.time(10, 35), '85:22:2096:000'), (1, 8506359, datetime.time(10, 44), '85:22:2105:000'), (0, 8518100, datetime.time(10, 42), '85:22:2105:000')]
# '8518459': [(0, 8518459, datetime.time(10, 39), 'ch:1:sjyid:100001:18541-001'), (1, 8502227, datetime.time(10, 41), 'ch:1:sjyid:100001:18541-001'), (0, 8518459, datetime.time(10, 49), 'ch:1:sjyid:100001:18536-001'), (0, 8518459, datetime.time(10, 9), 'ch:1:sjyid:100001:18539-001'), (1, 8502227, datetime.time(10, 11), 'ch:1:sjyid:100001:18539-001'), (0, 8518459, datetime.time(10, 19), 'ch:1:sjyid:100001:18534-001')]
# '8518690': [(0, 8518690, datetime.time(10, 40), '85:81:427:000'), (0, 8518690, datetime.time(10, 45), '85:81:428:000'), (1, 8500211, datetime.time(10, 46), '85:81:428:000'), (0, 8518690, datetime.time(10, 48), '85:81:9427:000'), (1, 8500211, datetime.time(10, 49), '85:81:9427:000')]
# '8518771': [(1, 8504419, datetime.time(10, 33), 'ch:1:sjyid:100001:7664-001'), (0, 8518771, datetime.time(11, 0), 'ch:1:sjyid:100001:7618-001'), (0, 8518771, datetime.time(10, 58), 'ch:1:sjyid:100001:7619-001')]
# '8518924': [(1, 8503423, datetime.time(11, 0), 'ch:1:sjyid:100001:18936-001'), (1, 8503423, datetime.time(10, 0), 'ch:1:sjyid:100001:18932-001'), (0, 8518924, datetime.time(10, 57), 'ch:1:sjyid:100001:18936-001'), (0, 8518924, datetime.time(10, 1), 'ch:1:sjyid:100001:18939-001'), (1, 8503421, datetime.time(10, 6), 'ch:1:sjyid:100001:18939-001'), (0, 8518924, datetime.time(10, 14), 'ch:1:sjyid:100046:8334-001'), (1, 8503423, datetime.time(10, 16), 'ch:1:sjyid:100046:8334-001'), (0, 8518924, datetime.time(10, 31), 'ch:1:sjyid:100046:8341-001')]
# '8518963': [(1, 8500206, datetime.time(10, 47), 'ch:1:sjyid:100001:7667-001'), (1, 8500205, datetime.time(10, 14), 'ch:1:sjyid:100001:7664-001'), (0, 8518963, datetime.time(10, 16), 'ch:1:sjyid:100001:7617-001'), (1, 8500206, datetime.time(10, 18), 'ch:1:sjyid:100001:7617-001'), (1, 8500205, datetime.time(10, 43), 'ch:1:sjyid:100001:7618-001'), (0, 8518963, datetime.time(10, 45), 'ch:1:sjyid:100001:7667-001'), (0, 8518963, datetime.time(10, 42), 'ch:1:sjyid:100001:7618-001')]
# '8519306': [(1, 8506371, datetime.time(10, 59), '85:22:2105:000'), (1, 8506371, datetime.time(10, 29), '85:22:2099:000'), (1, 8506302, datetime.time(10, 56), '85:22:2102:000'), (0, 8519306, datetime.time(10, 57), '85:22:2105:000'), (0, 8519306, datetime.time(10, 51), '85:22:2102:000')]
#
#
# Possible Paths:
# ch:1:sjyid:100001:18631(09:00:00) -> 001'8503000'(09:04:00) -> ch:1:sjyid:100001:514(09:30:00) -> 003'8503000'(09:40:00)
# ch:1:sjyid:100001:18631(09:00:00) -> 001'8503000'(10:04:00) -> ch:1:sjyid:100001:516(10:30:00) -> 001'8503000'(10:40:00)
# ch:1:sjyid:100001:18631(09:00:00) -> 001'8503000'(09:53:00) -> ch:1:sjyid:100061:2362(09:59:00) -> 005'8503000'(10:36:00)
